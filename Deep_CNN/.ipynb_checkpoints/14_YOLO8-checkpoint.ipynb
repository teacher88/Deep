# %%
# !pip install ultralytics

# %%
import numpy as np
import pandas as pd
import seaborn as sns

import matplotlib.pyplot as plt
import matplotlib.pyplot as plt             
import matplotlib as mpl                    
mpl.rc('font', family='Malgun Gothic')      
plt.rcParams['axes.unicode_minus']=False  

import ultralytics
from ultralytics import YOLO           # ultralytics에서 YOLO 모듈을 불러옴
import cv2

# %% [markdown]
# ## YOLO ver8
# - YOLO 시리즈중에 가볍고, 정확도가 높다
# - YOLO는 ultraytics에 개발
#     - ultraytics github : https://github.com/ultralytics/ultralytics

# %%
ultralytics.checks()
# Out:
# Ultralytics 8.3.109  Python-3.12.7 torch-2.6.0+cpu CPU (Intel Core(TM) i5-8250U 1.60GHz)
# Setup complete  (8 CPUs, 7.8 GB RAM, 28.2/48.8 GB disk)

# %% [markdown]
# - 객체
#     - Detect(검출)
#     - Segmentation(분할)
#     - Tracking(추적)
#     - Pose(포즈)

# %% [markdown]
# ## Dectection
# - 검출

# %%
# yolov8n.pt 모델의 아키텍처와 가중치을 함께 불러옴 >> yolv8n.pt 파일 생김
model=YOLO('yolov8n.pt')        

# 모델 예측 >> 원본이미지 자동저장, 예측 이미지 runs >> detect >> predict >> bus.jpg 저장
results=model.predict(source='https://ultralytics.com/images/bus.jpg', save=True)
# Out:
# Found https://ultralytics.com/images/bus.jpg locally at bus.jpg
# image 1/1 D:\Edu\Machine Learning\workspace\DeepLearing\bus.jpg: 640x480 4 persons, 1 bus, 1 stop sign, 162.7ms
# Speed: 8.8ms preprocess, 162.7ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 480)
# Results saved to runs\detect\predict2

# %%
img=cv2.imread('./runs/detect/predict/bus.jpg')
fix_width=400                   # 고정하고 싶은 가로 길이
height, width=img.shape[:2]     # (1080, 810) 원본 이미지 높이와 너비 추출
ratio=fix_width / width         # 0.49 너비 비율 계산
demension=(fix_width, int(height*ratio))   # 400, 533
img_resize=cv2.resize(img, demension, interpolation=cv2.INTER_AREA)   # 사이즈 변경, 보관법 축소

img=cv2.cvtColor(img_resize, cv2.COLOR_BGR2RGB)
plt.imshow(img)
plt.axis('off') 
plt.show()

# %% [markdown]
# ## Segmentation
# - 분할

# %%
# yolov8n-seg.pt 모델의 아키텍처와 가중치을 함께 불러옴
model=YOLO('yolov8n-seg.pt')

# 모델 예측
results=model.predict(source='https://ultralytics.com/images/bus.jpg', save=True)
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolov8n-seg.pt to 'yolov8n-seg.pt'...
# 100%|█████████████████████████████████████████████████████████████████████████████| 6.74M/6.74M [00:01<00:00, 5.45MB/s]
# Found https://ultralytics.com/images/bus.jpg locally at bus.jpg
# image 1/1 D:\Edu\Machine Learning\workspace\DeepLearing\bus.jpg: 640x480 4 persons, 1 bus, 1 skateboard, 243.4ms
# Speed: 6.7ms preprocess, 243.4ms inference, 19.8ms postprocess per image at shape (1, 3, 640, 480)
# Results saved to runs\segment\predict

# %%
img=cv2.imread('./runs/segment/predict/bus.jpg')
fix_width=400
height, width=img.shape[:2]
ratio=fix_width / width
demension=(fix_width, int(height * ratio))
img_resize=cv2.resize(img, demension, interpolation=cv2.INTER_AREA)

img=cv2.cvtColor(img_resize, cv2.COLOR_BGR2RGB)
plt.imshow(img)
plt.axis('off') 
plt.show()

# %% [markdown]
# ## Pose

# %%
# yolov8n-seg.pt 모델의 아키텍처와 가중치을 함께 불러옴
model=YOLO('yolov8n-pose.pt')

# 모델 예측
results=model.predict(source='https://ultralytics.com/images/bus.jpg', save=True)
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolov8n-pose.pt to 'yolov8n-pose.pt'...
# 100%|█████████████████████████████████████████████████████████████████████████████| 6.52M/6.52M [00:00<00:00, 10.2MB/s]
# Found https://ultralytics.com/images/bus.jpg locally at bus.jpg
# image 1/1 D:\Edu\Machine Learning\workspace\DeepLearing\bus.jpg: 640x480 4 persons, 210.5ms
# Speed: 6.7ms preprocess, 210.5ms inference, 5.2ms postprocess per image at shape (1, 3, 640, 480)
# Results saved to runs\pose\predict

# %%
img=cv2.imread('./runs/pose/predict/bus.jpg')
fix_width=400
height,width=img.shape[:2]
ratio=fix_width / width
demension=(fix_width, int(height*ratio))
img_resize=cv2.resize(img, demension, interpolation=cv2.INTER_AREA)

img=cv2.cvtColor(img_resize, cv2.COLOR_BGR2RGB)
plt.imshow(img)
plt.axis('off') 
plt.show()

# %%
# yolov8n.pt 모델의 아키텍처와 가중치을 함께 불러옴
model=YOLO('yolov8n.pt')        

# 모델 예측 >> 이미지 자동 저장 
results=model.predict(source='./Data/fruit/orgin/fruit01.jpg', save=True)
# Out:
# image 1/1 D:\Edu\Machine Learning\workspace\DeepLearing\Data\fruit\orgin\fruit01.jpg: 480x640 2 apples, 4 oranges, 200.2ms
# Speed: 7.1ms preprocess, 200.2ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\detect\predict2

# %%
img=cv2.imread('./runs/detect/predict2/fruit01.jpg')
fix_width=400                  # 고정하고 싶은 가로 길이
height,width=img.shape[:2]     # (1080, 810) 원본 이미지 높이와 너비 추출
ratio=fix_width / width        # 0.49 너비 비율 계산
demension=(fix_width, int(height*ratio))   # 400, 533
img_resize=cv2.resize(img, demension, interpolation=cv2.INTER_AREA)   # 사이즈 변경

img=cv2.cvtColor(img_resize, cv2.COLOR_BGR2RGB)
plt.imshow(img)
plt.axis('off') 
plt.show()
